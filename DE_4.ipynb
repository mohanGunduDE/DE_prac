# %%
schema = {
    "order_id": "O101",
    "customer_id": "C001",
    "order_line_items": [
        {
            "item_id": "I001",
            "qty": 6,
            "amount": 102.45
        },
        {
            "item_id": "I003",
            "qty": 2,
            "amount": 2.01
        }
    ],
    "contact": [9000010000, 9000010000]
}

# %%
df = spark.read.format("json").load("/Workspace/Users/gm001114951@techmahindra.com/schema.json")

# %%
df.show()
