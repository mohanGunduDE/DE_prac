# %%
dep = "/Volumes/workspace/databricks_prac/prac_1/department.csv"
emp = "/Volumes/workspace/databricks_prac/prac_1/employee.csv"

df_dep = spark.read.format("csv") \
        .option("header", "true") \
        .option("inferSchema", "true") \
        .load(dep)

df_emp = spark.read.format("csv") \
        .option("header", "true") \
        .option("inferSchema", "true") \
        .load(emp)  

display(df_dep)
display(df_emp)

# %%
df = df_dep.join(df_emp, df_dep.user == df_emp.emp_id, "outer")
display(df)

# %%
dep_n = "/Volumes/workspace/databricks_prac/prac_1/department_1.csv"

df_dep_n = spark.read.format("csv") \
        .option("header", "true") \
        .option("inferSchema", "true") \
        .load(dep_n)

display(df_dep_n)

# %%
#display(df_dep)
#display(df_dep_n)

df_join = df_dep.join(df_dep_n, df_dep.user == df_dep_n.user,"left_semi")
display(df_join)

# %%
#display(df_dep_n)
#display(df_dep)

join = df_dep.join(df_dep_n, df_dep.user == df_dep_n.user,"left_semi")
display(join)

# %%
#df_dep.show()
from pyspark.sql.functions import *
txt = df_dep.withColumn("new", lit("use"))
display(txt)

# %%
display(df_dep)
