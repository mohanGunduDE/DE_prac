# %%
def funct("microBatchDF",BatchID):
	microBatchDF.createorReplaceTempView("testing")
 
 query = '''  ''' 

microBatchDF.sparkSession.sql(query)

# %%
df = Spark.writeStream.format("cloudFiles").option("cloudFile.format","csv").foreachBatch(funct).start()
