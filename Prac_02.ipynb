# %%
path = "/Volumes/workspace/databricks_prac/prac_1/sample.csv"

df = spark.read.format("csv") \
    .option("Header" ,"true") \
    .option("schemainterfer", "true") \
    .load(path)

display(df.na.fill("NA",["city"]))
