# %%
# %sql

SELECT *
FROM csv.`databricks-datasets/retail.org/company-employees/company-employees.csv`

# %%
df = spark.read.format("csv").options("header",True),option("header",True).load("databricks-datasets/retail.org/company-employees/company-employees.csv")

display(df)

# %%
# %sql
