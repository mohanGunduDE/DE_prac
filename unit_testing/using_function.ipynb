# %%
# %run /Workspace/Users/gm001114951@techmahindra.com/unit_testing/test_modules

# %%
from pyspark.sql.functions import *

data = [(1, "Alice", 65),
        (2, "Bob", 55),
        (3, "Charlie", 70),
        (4, "David", 45)
        ]
df = spark.createDataFrame(data, ["id", "name", "age"])
df_fil = age_filter(df,"age")
display(df_fil)
